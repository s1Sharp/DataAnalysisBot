# %%
surnames = ['vok', 'Вокулин']
idcards = [42342, 712312]
groupnumbers = ['5435', '09-712']

# %%
import pandas as pd

df = pd.DataFrame({'surname': surnames, 'idcard': idcards, 'group': groupnumbers, 'grage':[]})
# Out:
#   File "<ipython-input-4-160d3bc8a3bb>", line 3
#     df = pd.DataFrame({'surname': surnames, 'idcard': idcards, 'group': groupnumbers, 'grage'})
#                                                                                              ^
# SyntaxError: invalid syntax
